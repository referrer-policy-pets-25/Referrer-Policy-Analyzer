# %%
# Re-importing the necessary libraries
import sys
sys.path.append('..')

import ujson as json
import pandas as pd
import glob
from os.path import basename
import re
from helpers.utils import is_failed_visit

# %%
def get_all_reqs(path):
    """
    Extracts request information from the JSON files in the given path.
    
    Args:
    path (str): The path to the JSON files containing the request data.
    
    Returns:
    reqDF (pd.DataFrame): A DataFrame containing the request information.
    """

    attr_list = []
    meta_list = []
    # dir_path = os.path.dirname(path)

    for json_path in glob.glob(path):
        json_name = basename(json_path)

        try:
            with open(json_path) as file:
                results = json.load(file)
        except Exception as e:
            print("ERROR: Cannot load the json", json_name, e)
            continue

        # Get visit metadata and check whether it should be processed
        try:
            init_url = results["initialUrl"]
            final_url = results["finalUrl"]

            failed_visit = is_failed_visit(results)
        except Exception as err:
            continue
        try:
            linkAttributes = results["data"]["elementAttributes"]
            for link in linkAttributes["elmAttrs"]:
                # print("--site_domain--", site_domain)
                href = link['href']
                src = link['src']
                rel = link['rel']
                referrerpolicy = link['linkReferrerPolicy']
                title = link['title']
                text = link['text']
                frameUrl = link['frameUrl']
                tagName = link['tagName']
                isFrame = link['inFrame']
                type = link['type']
                crossorigin = link['crossorigin']
                as_attr = link['as']
                integrity = link['integrity']
                link_details = (init_url, final_url ,failed_visit ,href, src, rel, referrerpolicy, 
                                title, text, frameUrl, tagName, isFrame, type, 
                                crossorigin, as_attr, integrity)
                attr_list.append(link_details)
        except Exception as err:
            print('Error elemAttrb', init_url, err)
        try:
            for meta in linkAttributes["metaRP"]:
                referrer_policy = meta["metaReferrerContent"]
                # print(referrer_policy)
                frameUrl = meta['frameUrl']
                inFrame = meta['inFrame']
                pageURL = meta['pageUrl']
                # print (pageURL)
                metadata_details = (init_url, final_url ,failed_visit ,referrer_policy, frameUrl, inFrame, pageURL)
                meta_list.append(metadata_details)
        except Exception as err:
            print('Error meta', init_url, err)
        
            
    
    attr_df = pd.DataFrame(attr_list, columns=[
        'init_url', 'final_url','failed_visit', 'href', 'src', 'rel', 
        'referrerpolicy', 'title', 'text', 
        'frameUrl', 'tagName', 'isFrame', 'type', 'crossorigin', 'as_attr', 'integrity'])
    # attrDF.to_json(saved_req_file_path.replace('requests', 'linkAttrs'), orient='records')
    
    meta_df = pd.DataFrame(meta_list, columns=[
        'init_url', 'final_url' ,'failed_visit' ,'referrer_policy', 'frameUrl', 'inFrame', 'pageURL'])


    return attr_df, meta_df

# %%
# folder path
# folder_path = '/data/referrer-policy/Small_scale_crawl/2025-02-08_noAct/*.json'
folder_path = '/data/referrer-policy/SF/2024-01-24_inner_collector_SF/*.json'


pattern_type = r'(\d{4}-\d{2}-\d{2})_([^/]+)'
match_type = re.search(pattern_type, folder_path)

if match_type:
    extract_date, extract_type = match_type.groups()
    if "inner_collector" in extract_type:
        extract_type = extract_type.replace("inner_collector_", "")
    print("Date:", extract_date)
    print("Type:", extract_type)
else:
    print("No match found.")
# Out:
# Date: 2024-01-24
# Type: SF

# %%
df_attr, df_meta = get_all_reqs(folder_path)
# Out:
# Error elemAttrb https://www.vaned.com/index.cfm/fa/ce/fa2/home 'text'
# Error elemAttrb http://rss.infodsi.com/ 'text'
# Error elemAttrb https://www.villarddelans-correnconenvercors.com/#tabs-65a9c8a9de58d 'text'
# Error elemAttrb https://clasificadosonline.com/empleos 'text'
# Error elemAttrb https://masterbuilders.com.au/campaigns 'text'
# Error elemAttrb https://skateboardshopsunabe.com/?mode=cate&cbid=139613&csid=2&sort=n 'text'
# Error elemAttrb https://study.wearefamilyfoundation.org/ 'text'
# Error elemAttrb https://apogee.net/solutions/low-and-moderate-income 'text'
# Error elemAttrb https://www.myresortnetwork.com/search-vacation-rentals/index.asp 'text'
# Error elemAttrb https://www.tourisme-saintomer.com/#pagesection-0 'text'
# Error elemAttrb https://www.green-acres.gr/%ce%b1%ce%ba%ce%af%ce%bd%ce%b7%cf%84%ce%b1/%ce%b9%ce%bf%ce%bd%ce%b9%ce%b1-%ce%bd%ce%b7%cf%83%ce%b9%ce%b1 'text'
# Error elemAttrb https://www.simplyscratch.com/feed 'text'
# Error elemAttrb https://stxaviersschool.com/origin 'text'
# Error elemAttrb https://www.horizen.io/en 'text'
# Error elemAttrb http://www.only-r.com/news/rss 'text'
# Error elemAttrb https://www.canadianinstitute.com/conferences/in-person 'text'
# Error elemAttrb http://anihatsu.com/index.rdf 'text'
# Error elemAttrb https://www.mildicasdemae.com.br/2024/01/convivencia-entre-animais-e-criancas.html 'text'
# Error elemAttrb https://lawtigers.com/resources/client-success-stories 'text'
# Error elemAttrb https://www.villarddelans-correnconenvercors.com/#tabs-65a9c8a9deeb6 'text'
# Error elemAttrb https://stmichaelsmount.co.uk/shopping-eating/the-island-cafe 'text'
# Error elemAttrb https://www.tourisme-saintomer.com/s-emerveiller 'text'
# Error elemAttrb https://landjugend.at/news 'text'
# Error elemAttrb https://www.5vorflug.de/angebote/urlaubsziele.html 'text'
# Error elemAttrb https://masterbuilders.com.au/newsroom 'text'
# Error elemAttrb https://masterbuilders.com.au/policies 'text'
# Error elemAttrb https://qsds.go.th/feed 'text'
# Error elemAttrb https://www.starbucks.com.au/merchandise/faqs 'text'
# Error elemAttrb https://link.outdoorlife.com/join/79r/signup-outdoor-life 'text'
# Error elemAttrb https://fa.atabat.org/ 'text'
# Error elemAttrb https://weatherbyhealthcare.com/locum-tenens-physician-assistant-jobs/all 'text'
# Error elemAttrb https://apogee.net/solutions/revenue-enhancement 'text'
# Error elemAttrb https://www.green-acres.gr/%ce%b1%ce%ba%ce%af%ce%bd%ce%b7%cf%84%ce%b1/%cf%83%cf%84%ce%b5%cf%81%ce%b5%ce%b1-%ce%b5%ce%bb%ce%bb%ce%b1%ce%b4%ce%b1 'text'
# Error elemAttrb https://www.mildicasdemae.com.br/category/criacao-de-filhos 'text'
# Error elemAttrb https://www.herault-tourisme.com/fr/outils/mentions-legales 'text'
# Error elemAttrb https://www.headout.com/cities 'text'
# Error elemAttrb https://www.liberationnews.org/feed 'text'
# Error elemAttrb https://lawtigers.com/resources/motorcycle-accident-faqs 'text'
# Error elemAttrb https://www.etias.info/cookies 'text'
# Error elemAttrb https://schwebebahn.de/en 'text'
# Error elemAttrb https://speedtest.zirrus.com/ 'text'
# Error elemAttrb https://silkyoakslodge.com.au/packages 'text'
# Error elemAttrb https://www.starbucks.com.au/menu/beverages 'text'
# Error elemAttrb https://www.canadianinstitute.com/conferences/?type=c5_event 'text'
# Error elemAttrb https://www.prayerandpossibilities.com/category/trust-god 'text'
# Error elemAttrb https://cornmazesandmore.org/#modalsearch 'text'
# Error elemAttrb https://skateboardshopsunabe.com/?mode=cate&cbid=304820&csid=5&sort=n 'text'
# Error elemAttrb https://skateboardshopsunabe.com/?mode=f3 'text'
# Error elemAttrb https://masterbuilders.com.au/excelling-building-and-construction-businesses-celebrated 'text'
# Error elemAttrb https://wmasteru.org/forums/python.116/index.rss 'text'
# Error elemAttrb https://schwebebahn.de/stationen 'text'
# Error elemAttrb https://wmasteru.org/forums/php.82/index.rss 'text'
# Error elemAttrb https://stmichaelsmount.co.uk/explore-the-mount/live-webcam 'text'
# Error elemAttrb https://www.hourly.io/workers-comp 'text'
# Error elemAttrb https://voltage.cloud/support 'text'
# Error elemAttrb https://www.modelbouwforum.nl/forum/nvm-nieuws.198/index.rss 'text'
# Error elemAttrb https://www.modelbouwforum.nl/forum/wordt-vriend-van-het-forum.215/index.rss 'text'
# Error elemAttrb https://www.herault-tourisme.com/fr/#m-bien-manger 'text'
# Error elemAttrb https://www.horizen.io/news 'text'
# Error elemAttrb https://silkyoakslodge.com.au/spa 'text'
# Error elemAttrb https://silkyoakslodge.com.au/dine 'text'
# Error elemAttrb https://www.horizen.io/community 'text'
# Error elemAttrb https://www.starbucks.com.au/merchandise/terms-conditions 'text'
# Error elemAttrb https://genealogy-specialists.com/forums/welcome-to-our-genealogy-forum.444/index.rss 'text'
# Error elemAttrb https://www.tourisme-saintomer.com/s-inspirer 'text'
# Error elemAttrb https://smartsolar.com.my/evacuated-tube-solar-collector-vs-flat-plate 'text'
# Error elemAttrb https://fastmailstatus.com/default/history.atom 'text'
# Error elemAttrb https://stmichaelsmount.co.uk/explore-the-mount/the-stewards-house 'text'
# Error elemAttrb https://www.cornmazesandmore.org/index.php#states 'text'
# Error elemAttrb https://www.mildicasdemae.com.br/2024/01/pre-natal-com-pediatra.html 'text'
# Error elemAttrb https://www.canadianinstitute.com/conferences/by-location 'text'
# Error elemAttrb https://www.paieterno.com.br/tv-pai-eterno/#anchor-where 'text'
# Error elemAttrb https://secutec.be/solutions 'text'
# Error elemAttrb https://skateboardshopsunabe.com/?mode=cate&cbid=1472422&csid=0&sort=n 'text'
# Error elemAttrb https://theaudacitytopodcast.com/podcastfeed 'text'
# Error elemAttrb https://pogoda.onet.pl/ 'text'
# Error elemAttrb https://www.mildicasdemae.com.br/category/papo-de-mae 'text'
# Error elemAttrb https://www.prayerandpossibilities.com/start-here 'text'
# Error elemAttrb https://www.green-acres.gr/%ce%b1%ce%ba%ce%af%ce%bd%ce%b7%cf%84%ce%b1/%ce%b4%cf%85%cf%84%ce%b9%ce%ba%ce%b7-%ce%b5%ce%bb%ce%bb%ce%b1%ce%b4%ce%b1 'text'
# Error elemAttrb http://www.mikrotax.org/radiolaria/index.php?dir=rads_cenozoic 'text'
# Error elemAttrb https://fashionseoul.com/feed 'text'
# Error elemAttrb https://spotlightonpoverty.org/states 'text'
# Error elemAttrb https://landjugend.at/programm/allgemeinbildung/schwerpunktthema 'text'
# Error elemAttrb https://stmichaelsmount.co.uk/explore-the-mount/the-sheila-hitchens-collection1 'text'
# Error elemAttrb https://silkyoakslodge.com.au/#main 'text'
# Error elemAttrb https://apogee.net/solutions/self-service 'text'
# Error elemAttrb https://stxaviersschool.com/about-us 'text'
# Error elemAttrb https://weatherbyhealthcare.com/privacy-policy 'text'
# Error elemAttrb https://pogoda.onet.pl/smog 'text'
# Error elemAttrb https://www.tourisme-saintomer.com/sejourner 'text'
# Error elemAttrb https://apogee.net/solutions/rate-transformation 'text'
# Error elemAttrb https://retrocalage.com/#carte 'text'
# Error elemAttrb https://system.logist-pro.su/auth/login 'text'
# Error elemAttrb https://stmichaelsmount.co.uk/explore-the-mount/history-legends 'text'
# Error elemAttrb http://crx7601.com/index.rdf 'text'
# Error elemAttrb https://skateboardshopsunabe.com/?mode=grp&gid=1740656&sort=n 'text'
# Error elemAttrb https://silkyoakslodge.com.au/experience 'text'
# Error elemAttrb https://www.shorelinemedia.net/buyers_guide 'text'
# Error elemAttrb https://www.herault-tourisme.com/fr/#pop_affiche 'text'
# Error elemAttrb https://www.headout.com/help 'text'
# Error elemAttrb https://landjugend.at/galerien 'text'
# Error elemAttrb https://wmasteru.org/forums/net.114/index.rss 'text'
# Error elemAttrb https://cornmazesandmore.org/#states 'text'
# Error elemAttrb https://www.starbucks.com.au/coffee/coffee-tasting 'text'
# Error elemAttrb https://smartsolar.com.my/features/efficiency 'text'
# Error elemAttrb https://hempsupporter.com/state-action 'text'
# Error elemAttrb https://smartsolar.com.my/features/smart 'text'
# Error elemAttrb https://pgg.pl/rss 'text'
# Error elemAttrb https://www.herault-tourisme.com/fr/#m-mes-activites 'text'
# Error elemAttrb https://www.mildicasdemae.com.br/2024/01/medo-da-vacina.html 'text'
# Error elemAttrb https://landjugend.at/lj-akademie 'text'
# Error elemAttrb https://www.deutscheweine.de/regionen 'text'
# Error elemAttrb http://igoro.com/feed 'text'
# Error elemAttrb https://www.salvilaw.com/#video-popup-modal-desktop 'text'
# Error elemAttrb https://www.green-acres.gr/%ce%b1%ce%ba%ce%af%ce%bd%ce%b7%cf%84%ce%b1/%cf%80%ce%b5%ce%bb%ce%bf%cf%80%ce%bf%ce%bd%ce%bd%ce%b7%cf%83%ce%bf%cf%82 'text'
# Error elemAttrb https://vitals.co/affiliates 'text'
# Error elemAttrb https://www.prayerandpossibilities.com/category/spiritual-disciplines 'text'
# Error elemAttrb https://ajtel.net/w/interneteventos 'text'
# Error elemAttrb https://www.starbucks.com.au/menu/food 'text'
# Error elemAttrb https://www.etias.info/application 'text'
# Error elemAttrb https://wmasteru.org/forums/javascript.87/index.rss 'text'
# Error elemAttrb https://www.tourisme-saintomer.com/sortir 'text'
# Error elemAttrb https://masterbuilders.com.au/events 'text'
# Error elemAttrb https://www.vaned.com/index.cfm/fa/pre/fa2/home 'text'
# Error elemAttrb https://www.modelbouwforum.nl/forum/mbf-nieuws.11/index.rss 'text'
# Error elemAttrb https://grantome.com/search 'text'
# Error elemAttrb https://weatherbyhealthcare.com/locum-tenens-physician-jobs 'text'
# Error elemAttrb https://weatherbyhealthcare.com/locum-tenens-nurse-practitioner-jobs/all 'text'
# Error elemAttrb https://www.americantrapshooter.com/forums/your-pictures-trapshooting-sporting-clays-etc.124/index.rss 'text'
# Error elemAttrb https://jafmate.co.jp/feed 'text'
# Error elemAttrb https://landjugend.at/termine 'text'
# Error elemAttrb https://www.canadianinstitute.com/conferences/by-sector 'text'
# Error elemAttrb https://voltage.cloud/terms 'text'
# Error elemAttrb https://www.herault-tourisme.com/fr/gagnez-vos-loisirs 'text'
# Error elemAttrb https://www.canadianinstitute.com/conferences/virtual 'text'
# Error elemAttrb https://www.koeln.de/leben 'text'
# Error elemAttrb https://www.exact.com/nl/producten/accountancy 'text'
# Error elemAttrb http://www.castleproject.org/feed 'text'
# Error elemAttrb https://www.etias.info/schengen-countries 'text'
# Error elemAttrb https://www.etias.info/visa-requirements 'text'
# Error elemAttrb https://www.prayerandpossibilities.com/blog 'text'
# Error elemAttrb https://www.americantrapshooter.com/forums/trapshooting-forum-americantrapshooter-com.7/index.rss 'text'
# Error elemAttrb https://www.etias.info/#icon-angle-down 'text'

# %%
df_attr.head()
# Out:
#                        init_url                     final_url  failed_visit  \
# 0  https://hippocampus.org/#1_7  https://hippocampus.org/#1_7         False
# 1  https://hippocampus.org/#1_7  https://hippocampus.org/#1_7         False
# 2  https://hippocampus.org/#1_7  https://hippocampus.org/#1_7         False
# 3  https://hippocampus.org/#1_7  https://hippocampus.org/#1_7         False
# 4  https://hippocampus.org/#1_7  https://hippocampus.org/#1_7         False
#
#                                                 href   src         rel  \
# 0  /HippoCampus/style/hippoUniversal.css;jsession...  None  stylesheet
# 1  /HippoCampus/style/twoPanelNavigator.css;jsess...  None  stylesheet
# 2  /HippoCampus/style/welcomeBox.css;jsessionid=5...  None  stylesheet
# 3  /HippoCampus/style/collectionsMenu.css;jsessio...  None  stylesheet
# 4  /HippoCampus/style/standardPopup.css;jsessioni...  None  stylesheet
#
#   referrerpolicy title text                      frameUrl tagName  isFrame  \
# 0           None  None       https://hippocampus.org/#1_7    link    False
# 1           None  None       https://hippocampus.org/#1_7    link    False
# 2           None  None       https://hippocampus.org/#1_7    link    False
# 3           None  None       https://hippocampus.org/#1_7    link    False
# 4           None  None       https://hippocampus.org/#1_7    link    False
#
#        type crossorigin as_attr integrity
# 0  text/css        None    None      None
# 1  text/css        None    None      None
# 2  text/css        None    None      None
# 3  text/css        None    None      None
# 4  text/css        None    None      None

# %%
df_meta
# Out:
#                                                 init_url  \
# 0      https://souffle.life/manga/ohayou-oyasumi-mata...
# 1      https://souffle.life/manga/ohayou-oyasumi-mata...
# 2                  https://www.1800tequila.com/our-story
# 3      https://xxxboard.net/member.php?30-flash&s=bfa...
# 4                https://uiowa.edu/academics/areas-study
# ...                                                  ...
# 16219  https://www.gourmetgiftbaskets.com/corporate-g...
# 16220  https://www.techfinehelp.in/2022/05/instagram-...
# 16221                 http://povarixa.ru/world-cook.html
# 16222  https://www.ruralheritage.com/new_rh_website/c...
# 16223         https://sex-video.live/category/small-girl
#
#                                                final_url  failed_visit  \
# 0      https://souffle.life/manga/ohayou-oyasumi-mata...         False
# 1      https://souffle.life/manga/ohayou-oyasumi-mata...         False
# 2                 https://www.1800tequila.com/our-story/         False
# 3      https://xxxboard.net/member.php?30-flash&s=bfa...         False
# 4                https://uiowa.edu/academics/areas-study         False
# ...                                                  ...           ...
# 16219  https://www.gourmetgiftbaskets.com/corporate-g...         False
# 16220  https://www.techfinehelp.in/2022/05/instagram-...         False
# 16221                 http://povarixa.ru/world-cook.html         False
# 16222  https://www.ruralheritage.com/new_rh_website/c...         False
# 16223         https://sex-video.live/category/small-girl         False
#
#                   referrer_policy  \
# 0         origin-when-crossorigin
# 1         origin-when-crossorigin
# 2                          origin
# 3                      unsafe-url
# 4      no-referrer-when-downgrade
# ...                           ...
# 16219                      origin
# 16220                      origin
# 16221                      origin
# 16222     origin-when-crossorigin
# 16223    origin-when-cross-origin
#
#                                                 frameUrl  inFrame  \
# 0      https://www.facebook.com/v3.2/plugins/share_bu...     True
# 1      https://www.facebook.com/v3.2/plugins/share_bu...     True
# 2      https://pay.google.com/gp/p/ui/payframe?origin...     True
# 3      https://xxxboard.net/member.php?30-flash&s=bfa...    False
# 4                https://uiowa.edu/academics/areas-study    False
# ...                                                  ...      ...
# 16219  https://www.google.com/shopping/customerreview...     True
# 16220  https://www.blogger.com/comment/frame/67039747...     True
# 16221                 http://povarixa.ru/world-cook.html    False
# 16222  https://www.facebook.com/plugins/like.php?href...     True
# 16223         https://sex-video.live/category/small-girl    False
#
#                                                  pageURL
# 0      https://souffle.life/manga/ohayou-oyasumi-mata...
# 1      https://souffle.life/manga/ohayou-oyasumi-mata...
# 2                 https://www.1800tequila.com/our-story/
# 3      https://xxxboard.net/member.php?30-flash&s=bfa...
# 4                https://uiowa.edu/academics/areas-study
# ...                                                  ...
# 16219  https://www.gourmetgiftbaskets.com/corporate-g...
# 16220  https://www.techfinehelp.in/2022/05/instagram-...
# 16221                 http://povarixa.ru/world-cook.html
# 16222  https://www.ruralheritage.com/new_rh_website/c...
# 16223         https://sex-video.live/category/small-girl
#
# [16224 rows x 7 columns]

# %%
df_attr.to_pickle("../output/data_raw/"+ extract_date + '_' + extract_type +'_attr.pkl')

# %%
df_meta.to_parquet("../output/data_raw/"+ extract_date + '_' + extract_type +'_meta.parquet')
